# %%
import os
import numpy as np
import pandas as pd

# Load Google Colab #
from google.colab import drive
drive.mount('/content/drive')

# Change to Working Directory #
os.chdir("/content/drive/MyDrive/510- Group Project")
# Out:
# Mounted at /content/drive

# %%
os.listdir()
# Out:
# ['Rose (3).csv',
#  'Red (3).csv',
#  'White (3).csv',
#  'Rose (2).csv',
#  'White (2).csv',
#  'Sparkling (3).csv',
#  'Sparkling (2).csv',
#  'Rose (1).csv',
#  'White (1).csv',
#  'Red (2).csv',
#  'Sparkling (1).csv',
#  'Red (1).csv',
#  'Sparkling.csv',
#  'Rose.csv',
#  'Red.csv',
#  'White.csv',
#  'Varieties.csv',
#  'DSO 510 Project - Eli.ipynb',
#  'DSO 510 Project .ipynb']

# %%
red_df = pd.read_csv("Red.csv")
red_df['wine_type'] = 'Red'
red_df.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year wine_type
# 0  Château La Providence     4.2              100  95.00  2011       Red
# 1     Château Mont-Redon     4.3              100  15.50  2017       Red
# 2             Renzo Masi     3.9              100   7.45  2015       Red
# 3             Cavalchina     3.5              100   8.72  2019       Red
# 4            Markowitsch     3.9              100  29.15  2016       Red

# %%
rose_df = pd.read_csv("Rose.csv")
rose_df['wine_type'] = 'Rose'
rose_df.head()
# Out:
#                                Name   Country        Region  \
# 0        Mad Méditerranée Rosé 2019    France  Méditerranée
# 1                  Redoma Rosé 2019  Portugal         Douro
# 2  Fantini Cerasuolo d'Abruzzo 2019     Italy       Abruzzo
# 3            Mount Hermon Rosé 2017    Israel       Galilee
# 4                La Villa Rosé 2018    France     Languedoc
#
#                    Winery  Rating  NumberOfRatings  Price  Year wine_type
# 0      Château Camparnaud     4.0               25  10.11  2019      Rose
# 1                Niepoort     3.9               25  12.81  2019      Rose
# 2                 Farnese     3.6               25   5.60  2019      Rose
# 3                  Hermon     3.4               25  12.14  2017      Rose
# 4  Château La Sauvageonne     4.6               25  68.95  2018      Rose

# %%
white_df = pd.read_csv("White.csv")
white_df['wine_type'] = 'White'
white_df.head()
# Out:
#                       Name  Country                      Region  \
# 0          Vermentino 2017    Italy                     Toscana
# 1        Ronco Broilo 2010    Italy  Colli Orientali del Friuli
# 2  Weisser Schiefer s 2017  Austria               Südburgenland
# 3          Chardonnay 2018  Germany                 Rheinhessen
# 4     Maganza Zibibbo 2018    Italy             Terre Siciliane
#
#                     Winery  Rating  NumberOfRatings  Price  Year wine_type
# 0      Famiglia Castellani     3.8               25   5.65  2017     White
# 1  Conte d'Attimis Maniago     4.3               25  44.90  2010     White
# 2     Weinbau Uwe Schiefer     4.2               25  33.25  2017     White
# 3        Krämer - Straight     3.9               25   8.99  2018     White
# 4                Luna Gaia     3.9               25   8.60  2018     White

# %%
sparkling_df = pd.read_csv("Sparkling.csv")
sparkling_df['wine_type'] = 'Sparkling'
sparkling_df.head()
# Out:
#                                           Name      Country  \
# 0                   Crémant de Loire Brut 2017       France
# 1  Vicar's Choice Sauvignon Blanc Bubbles 2019  New Zealand
# 2                  Crémant de Limoux Brut N.V.       France
# 3                            Athesis Brut 2016        Italy
# 4     Blanc de Blancs Réserve Brut Nature N.V.      Germany
#
#                   Region            Winery  Rating  NumberOfRatings  Price  \
# 0       Crémant de Loire  Langlois-Chateau     3.9               25  14.41
# 1            Marlborough       Saint Clair     4.2               25  11.90
# 2      Crémant de Limoux       Prima Perla     3.5               25  14.32
# 3  Südtirol - Alto Adige          Kettmeir     4.0               25  21.50
# 4                  Pfalz            Eymann     3.9               25  31.18
#
#    Year  wine_type
# 0  2017  Sparkling
# 1  2019  Sparkling
# 2  N.V.  Sparkling
# 3  2016  Sparkling
# 4  N.V.  Sparkling

# %%
# prompt: combine all red, white, rose and sparkling dataframe

import pandas as pd
wine_df = pd.concat([red_df, white_df, rose_df, sparkling_df], axis=0)
wine_df.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year wine_type
# 0  Château La Providence     4.2              100  95.00  2011       Red
# 1     Château Mont-Redon     4.3              100  15.50  2017       Red
# 2             Renzo Masi     3.9              100   7.45  2015       Red
# 3             Cavalchina     3.5              100   8.72  2019       Red
# 4            Markowitsch     3.9              100  29.15  2016       Red

# %%
wine_df.shape
# Out:
# (13834, 9)

# %%
# prompt: show descriptive stats for all columns in wine_df

wine_df.describe(include='all')
# Out:
#                    Name Country Region          Winery        Rating  \
# count             13834   13834  13834           13834  13834.000000
# unique            10934      33    861            3505           NaN
# top     Chardonnay 2018   Italy  Rioja  Markus Molitor           NaN
# freq                 78    3919    385              73           NaN
# mean                NaN     NaN    NaN             NaN      3.865664
# std                 NaN     NaN    NaN             NaN      0.296427
# min                 NaN     NaN    NaN             NaN      2.200000
# 25%                 NaN     NaN    NaN             NaN      3.700000
# 50%                 NaN     NaN    NaN             NaN      3.900000
# 75%                 NaN     NaN    NaN             NaN      4.100000
# max                 NaN     NaN    NaN             NaN      4.900000
#
#         NumberOfRatings         Price   Year wine_type
# count      13834.000000  13834.000000  13834     13834
# ...

# %%
# prompt: show descriptive stats for all columns in wine_df and highlight Price and Rating in some way

#Stylize the output
def highlight_cols(s):
    if s.name in ['Price', 'Rating']:
        return ['color: red']*len(s)
    else:
        return ['']*len(s)

styled_desc = wine_df.describe(include='all').style.apply(highlight_cols)
styled_desc
# Out:
# <style type="text/css">
# #T_f1b87_row0_col4, #T_f1b87_row0_col6, #T_f1b87_row1_col4, #T_f1b87_row1_col6, #T_f1b87_row2_col4, #T_f1b87_row2_col6, #T_f1b87_row3_col4, #T_f1b87_row3_col6, #T_f1b87_row4_col4, #T_f1b87_row4_col6, #T_f1b87_row5_col4, #T_f1b87_row5_col6, #T_f1b87_row6_col4, #T_f1b87_row6_col6, #T_f1b87_row7_col4, #T_f1b87_row7_col6, #T_f1b87_row8_col4, #T_f1b87_row8_col6, #T_f1b87_row9_col4, #T_f1b87_row9_col6, #T_f1b87_row10_col4, #T_f1b87_row10_col6 {
#   color: red;
# }
# </style>
# <table id="T_f1b87" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1b87_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_f1b87_level0_col1" class="col_heading level0 col1" >Country</th>
#       <th id="T_f1b87_level0_col2" class="col_heading level0 col2" >Region</th>
#       <th id="T_f1b87_level0_col3" class="col_heading level0 col3" >Winery</th>
# ...

# %%
# prompt: sort the dataset with descnding order of Price

wine_df_sorted = wine_df.sort_values(by=['Price'], ascending=False)
wine_df_sorted.head()
# Out:
#                                                    Name Country  \
# 2344                                       Pomerol 2012  France
# 7466  Saint-Émilion Grand Cru (Premier Grand Cru Cla...  France
# 5560           Pauillac (Premier Grand Cru Classé) 2010  France
# 4395           Pauillac (Premier Grand Cru Classé) 1992  France
# 4124     Pessac-Léognan (Premier Grand Cru Classé) 2010  France
#
#                        Region                     Winery  Rating  \
# 2344                  Pomerol                     Pétrus     4.7
# 7466  Saint-Émilion Grand Cru             Château Ausone     4.5
# 5560                 Pauillac  Château Lafite Rothschild     4.4
# 4395                 Pauillac  Château Lafite Rothschild     4.5
# 4124           Pessac-Léognan         Château Haut-Brion     4.6
#
#       NumberOfRatings    Price  Year wine_type
# 2344              204  3410.79  2012       Red
# 7466               72  1599.95  2010       Red
# ...

# %%
# prompt: create a new dataset called filtered wine df without the Price=3410.79

filtered_wine_df = wine_df[wine_df['Price'] != 3410.79]
filtered_wine_df.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year wine_type
# 0  Château La Providence     4.2              100  95.00  2011       Red
# 1     Château Mont-Redon     4.3              100  15.50  2017       Red
# 2             Renzo Masi     3.9              100   7.45  2015       Red
# 3             Cavalchina     3.5              100   8.72  2019       Red
# 4            Markowitsch     3.9              100  29.15  2016       Red

# %%
# prompt: describe all column of dataset using describe function

filtered_wine_df.describe(include='all')
# Out:
#                    Name Country Region          Winery        Rating  \
# count             13833   13833  13833           13833  13833.000000
# unique            10934      33    861            3504           NaN
# top     Chardonnay 2018   Italy  Rioja  Markus Molitor           NaN
# freq                 78    3919    385              73           NaN
# mean                NaN     NaN    NaN             NaN      3.865604
# std                 NaN     NaN    NaN             NaN      0.296353
# min                 NaN     NaN    NaN             NaN      2.200000
# 25%                 NaN     NaN    NaN             NaN      3.700000
# 50%                 NaN     NaN    NaN             NaN      3.900000
# 75%                 NaN     NaN    NaN             NaN      4.100000
# max                 NaN     NaN    NaN             NaN      4.900000
#
#         NumberOfRatings         Price   Year wine_type
# count      13833.000000  13833.000000  13833     13833
# ...

# %%
# prompt: Box Plot → Price distribution across different rating levels not at wine type level

import matplotlib.pyplot as plt
import seaborn as sns
# Create the box plot
plt.figure(figsize=(10, 6))
sns.boxplot(x='Rating', y='Price', data=filtered_wine_df)
plt.title('Price Distribution across different rating levels')
plt.xlabel('Rating')
plt.ylabel('Price')
plt.show()

# %%
# prompt: create bucket of rating on 0.5 scale and give me number of wines falling into category

import pandas as pd
import numpy as np
# Assuming 'wine_df' is your DataFrame as defined in the previous code.

# Create rating buckets
bins = np.arange(0, 5.5, 0.5)  # Create bins from 0 to 5 with 0.5 intervals
labels = [f'{i}-{i+0.5}' for i in bins[:-1]] #Create labels for each bin

filtered_wine_df['rating_bucket'] = pd.cut(filtered_wine_df['Rating'], bins=bins, labels=labels, right=False)

# Count wines in each bucket
rating_counts = filtered_wine_df.groupby('rating_bucket')['Rating'].count()

rating_counts
# Out:
# <ipython-input-18-09def46e1864>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_wine_df['rating_bucket'] = pd.cut(filtered_wine_df['Rating'], bins=bins, labels=labels, right=False)
# <ipython-input-18-09def46e1864>:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   rating_counts = filtered_wine_df.groupby('rating_bucket')['Rating'].count()
# rating_bucket
# 0.0-0.5       0
# 0.5-1.0       0
# 1.0-1.5       0
# 1.5-2.0       0
# 2.0-2.5       1
# 2.5-3.0      23
# 3.0-3.5     972
# 3.5-4.0    7691
# 4.0-4.5    4775
# 4.5-5.0     371
# ...

# %%
# prompt: Histogram → Compare price distribution for high vs. low-rated wines

import matplotlib.pyplot as plt
# Define high and low rating thresholds
high_rating_threshold = 4.5
low_rating_threshold = 3.0

# Filter wines based on rating thresholds
high_rated_wines = filtered_wine_df[filtered_wine_df['Rating'] >= high_rating_threshold]
low_rated_wines = filtered_wine_df[filtered_wine_df['Rating'] <= low_rating_threshold]


# Create histograms for high and low-rated wines
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(high_rated_wines['Price'], bins=20, color='skyblue', edgecolor='black')
plt.title('Price Distribution of High-Rated Wines')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(low_rated_wines['Price'], bins=20, color='salmon', edgecolor='black')
plt.title('Price Distribution of Low-Rated Wines')
plt.xlabel('Price')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define rating thresholds
high_rating_threshold = 4.5
low_rating_threshold = 3.0

# Filter wines into three categories
high_rated_wines = filtered_wine_df[filtered_wine_df['Rating'] >= high_rating_threshold]
medium_rated_wines = filtered_wine_df[(filtered_wine_df['Rating'] > low_rating_threshold) &
                                      (filtered_wine_df['Rating'] < high_rating_threshold)]
low_rated_wines = filtered_wine_df[filtered_wine_df['Rating'] <= low_rating_threshold]

# Scatter plot for high, medium, and low-rated wines
plt.figure(figsize=(10, 6))

plt.scatter(high_rated_wines['Rating'], high_rated_wines['Price'],
            color='blue', alpha=0.6, label='High-Rated Wines (>= 4.5)')
plt.scatter(medium_rated_wines['Rating'], medium_rated_wines['Price'],
            color='green', alpha=0.6, label='Medium-Rated Wines (3.0 - 4.5)')
plt.scatter(low_rated_wines['Rating'], low_rated_wines['Price'],
            color='red', alpha=0.6, label='Low-Rated Wines (<= 3.0)')

# Labels and title
plt.xlabel('Rating')
plt.ylabel('Price')
plt.title('Price vs. Rating for High, Medium, and Low-Rated Wines')
plt.legend()
plt.grid(True)

plt.show()

# %%
# prompt: visualize rating vs price basis wine_type using dataset filtered wine df with y as Price and x as rating and colour Red as
#  red, white as grey, rose as  Pink and sparkling as Gold

import matplotlib.pyplot as plt
import seaborn as sns

# Create the scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Rating', y='Price', hue='wine_type', data=filtered_wine_df, palette={'Red': 'red', 'White': 'grey', 'Rose': 'pink', 'Sparkling': 'gold'})
plt.title('Wine Rating vs. Price by Wine Type')
plt.xlabel('Rating')
plt.ylabel('Price')
plt.show()

# %%
filtered_wine_df.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year wine_type  \
# 0  Château La Providence     4.2              100  95.00  2011       Red
# 1     Château Mont-Redon     4.3              100  15.50  2017       Red
# 2             Renzo Masi     3.9              100   7.45  2015       Red
# 3             Cavalchina     3.5              100   8.72  2019       Red
# 4            Markowitsch     3.9              100  29.15  2016       Red
#
#   rating_bucket
# 0       4.0-4.5
# 1       4.0-4.5
# 2       3.5-4.0
# 3       3.5-4.0
# 4       3.5-4.0

# %%
# prompt: vislalise relationship bwteen numberofrating , rating and price using filtered_wine_df

import matplotlib.pyplot as plt
# Assuming 'filtered_wine_df' is already defined as in your provided code.

plt.figure(figsize=(10, 6))
sns.scatterplot(x='NumberOfRatings', y='Price', hue='Rating', data=filtered_wine_df, palette='viridis')
plt.title('Relationship between Number of Ratings, Rating, and Price')
plt.xlabel('Number of Ratings')
plt.ylabel('Price')
plt.show()

# %%
# prompt: use country and create 2 graphs for rating and price vs Country

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'country' and 'rating' columns exist in your wine_df
# Replace 'rating' and 'price' with your actual column names if different

plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='Rating', data=filtered_wine_df)
plt.title('Average Rating by Country')
plt.xlabel('Country')
plt.ylabel('Average Rating')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels for better readability
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x='Country', y='Price', data=filtered_wine_df)
plt.title('Average Price by Country')
plt.xlabel('Country')
plt.ylabel('Average Price')
plt.xticks(rotation=45, ha='right') # Rotate x-axis labels
plt.show()

# %%
# prompt: use the two graphs above to show two world maps of wines by country showing prices and ratings in colour and remove any prices above 3000. reset the scale for prices to the mean values by country

import plotly.express as px

# Calculate the mean price for each country
mean_prices_by_country = filtered_wine_df.groupby('Country')['Price'].mean().reset_index()

# Create the first world map for prices
fig_price = px.choropleth(mean_prices_by_country, locations='Country', locationmode='country names',
                           color='Price', hover_name='Country',
                           title='Average Wine Price by Country (<= $3000)',
                           color_continuous_scale=px.colors.sequential.Plasma)
fig_price.show()

# Calculate the mean rating for each country
mean_ratings_by_country = filtered_wine_df.groupby('Country')['Rating'].mean().reset_index()

# Create the second world map for ratings
fig_rating = px.choropleth(mean_ratings_by_country, locations='Country', locationmode='country names',
                            color='Rating', hover_name='Country',
                            title='Average Wine Rating by Country',
                            color_continuous_scale=px.colors.sequential.Viridis)
fig_rating.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# prompt: import seaborn

import matplotlib.pyplot as plt
import seaborn as sns
# Assuming 'filtered_wine_df' is defined as in your previous code.
# Example usage: creating a pairplot
# sns.pairplot(filtered_wine_df, hue='wine_type', vars=['Price', 'Rating', 'NumberOfRatings'])
# plt.show()

# %%
# prompt: create a new dataframe where you remove all columns with year listed as N.V. and price is less than 3000 and visualise a correlation matrix between rating, number of ratings, price, and year. also explain the relationship between price and year. list the average price for year

import pandas as pd
import matplotlib.pyplot as plt
# Remove rows where 'Year' is 'N.V.' and 'Price' is less than 3000
# filtered_wine_df = wine_df[(wine_df['Year'] != 'N.V.') | (wine_df['Price'] >= 3000)]

# Select relevant columns for correlation and handle missing values
columns_for_correlation = ['Rating', 'NumberOfRatings', 'Price', 'Year']
correlation_df = filtered_wine_df[columns_for_correlation].dropna()

# Convert 'Year' to numeric, coercing errors to NaN
correlation_df['Year'] = pd.to_numeric(correlation_df['Year'], errors='coerce')
correlation_df = correlation_df.dropna(subset=['Year'])

# Calculate the correlation matrix
correlation_matrix = correlation_df.corr()

# Visualize the correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Wine Features')
plt.show()

# %%
# prompt: create a histogram to show the number of wines and reviews by year, use dataset filtered_wine_df

import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'filtered_wine_df' is already defined and loaded

# Convert 'Year' column to numeric, handling errors
filtered_wine_df['Year'] = pd.to_numeric(filtered_wine_df['Year'], errors='coerce')

# Drop rows with NaN values in the 'Year' column
filtered_wine_df = filtered_wine_df.dropna(subset=['Year'])


# Create the histogram
plt.figure(figsize=(12, 6))
plt.hist(filtered_wine_df['Year'], bins=20)  # Adjust the number of bins as needed
plt.xlabel('Year')
plt.ylabel('Number of Wines')
plt.title('Distribution of Wines by Year')
plt.show()

# Create a histogram for the number of reviews per year
plt.figure(figsize=(12,6))
plt.hist(filtered_wine_df['Year'], weights = filtered_wine_df['NumberOfRatings'], bins = 20)
plt.xlabel('Year')
plt.ylabel('Number of Reviews')
plt.title('Number of Reviews by Year')
plt.show()
# Out:
# <ipython-input-24-1ebd213d2d03>:9: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# prompt: create 2 graphs to show average rating and price for different year from dataset filtered_wine_df

import matplotlib.pyplot as plt
# Group data by year and calculate the average rating and price
yearly_data = filtered_wine_df.groupby('Year')[['Rating', 'Price']].mean().reset_index()

# Create the first plot for average rating
plt.figure(figsize=(10, 6))
plt.plot(yearly_data['Year'], yearly_data['Rating'], marker='o')
plt.title('Average Wine Rating per Year')
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.grid(True)
plt.show()

# Create the second plot for average price
plt.figure(figsize=(10, 6))
plt.plot(yearly_data['Year'], yearly_data['Price'], marker='o', color='orange')
plt.title('Average Wine Price per Year')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.grid(True)
plt.show()

# %%
# prompt: create a histogram of Price for red wine, with the x axis spanning from 0-200 with 10 buckets

import matplotlib.pyplot as plt

# Assuming red_df is already defined as in the previous example
plt.hist(red_df['Price'], range=(0, 200), bins=10)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Price for Red Wine')
plt.show()

# %%
# prompt: create side by side histograms of Price for red wine, white wine, and rose wine, with the x axis spanning from 0-100 with 10 buckets

import matplotlib.pyplot as plt

# Create the side-by-side histograms
plt.figure(figsize=(12, 6))  # Adjust figure size for better visualization

plt.subplot(1, 3, 1)  # 1 row, 3 columns, first subplot
plt.hist(red_df['Price'], range=(0, 100), bins=10, color='red', alpha=0.7)
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Red Wine')
plt.xlim(0,100)

plt.subplot(1, 3, 2)  # 1 row, 3 columns, second subplot
plt.hist(white_df['Price'], range=(0, 100), bins=10, color='white', edgecolor='black', alpha=0.7)
plt.xlabel('Price')
plt.title('White Wine')
plt.xlim(0,100)

plt.subplot(1, 3, 3)  # 1 row, 3 columns, third subplot
plt.hist(rose_df['Price'], range=(0, 100), bins=10, color='pink', alpha=0.7)
plt.xlabel('Price')
plt.title('Rose Wine')
plt.xlim(0,100)


plt.tight_layout()  # Adjust subplot parameters for a tight layout
plt.show()

# %%
# prompt: create side by side histograms of Rating for red wine, white wine, and rose wine

import pandas as pd
import matplotlib.pyplot as plt

# Assuming red_df, white_df, and rose_df are already defined as in the previous example

# Create the side-by-side histograms
plt.figure(figsize=(12, 6))  # Adjust figure size for better visualization

plt.subplot(1, 3, 1)  # 1 row, 3 columns, first subplot
plt.hist(red_df['Rating'], bins=10, color='red', alpha=0.7)
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.title('Red Wine')


plt.subplot(1, 3, 2)  # 1 row, 3 columns, second subplot
plt.hist(white_df['Rating'], bins=10, color='white', edgecolor='black', alpha=0.7)
plt.xlabel('Rating')
plt.title('White Wine')

plt.subplot(1, 3, 3)  # 1 row, 3 columns, third subplot
plt.hist(rose_df['Rating'], bins=10, color='pink', alpha=0.7)
plt.xlabel('Rating')
plt.title('Rose Wine')

plt.tight_layout()  # Adjust subplot parameters for a tight layout
plt.show()

# %%
# prompt: Create a scatterplot for red wine that shows rating vs price

import pandas as pd
import matplotlib.pyplot as plt

# Assuming red_df is already defined as in the previous example
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.scatter(red_df['Rating'], red_df['Price'], alpha=0.5)  # Create the scatter plot
plt.xlabel('Rating')
plt.ylabel('Price')
plt.title('Red Wine Rating vs. Price')
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
# prompt: Create a scatterplot for white wine that shows rating vs price

# Assuming white_df is already defined as in the previous example
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.scatter(white_df['Rating'], white_df['Price'], alpha=0.5)  # Create the scatter plot
plt.xlabel('Rating')
plt.ylabel('Price')
plt.title('White Wine Rating vs. Price')
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
# prompt: Create a scatterplot for rose wine that shows rating vs price

# Assuming rose_df is already defined as in the previous example
plt.figure(figsize=(8, 6))  # Adjust figure size if needed
plt.scatter(rose_df['Rating'], rose_df['Price'], alpha=0.5)  # Create the scatter plot
plt.xlabel('Rating')
plt.ylabel('Price')
plt.title('Rose Wine Rating vs. Price')
plt.grid(True)  # Add a grid for better readability
plt.show()

# %%
# prompt: For each country in the red wine dataset, create a histogram of Price, a histogram of Rating, and a scatterplot of Price vs. Rating

import pandas as pd
import matplotlib.pyplot as plt

# Assuming red_df is already defined and loaded with data
# If not, load the data first:
# red_df = pd.read_csv("Red.csv")

for country in red_df['Country'].unique():
    country_df = red_df[red_df['Country'] == country]

    # Price Histogram
    plt.figure(figsize=(8, 6))
    plt.hist(country_df['Price'], bins=10)
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.title(f'Price Histogram for {country} Red Wine')
    plt.show()

    # Rating Histogram
    plt.figure(figsize=(8, 6))
    plt.hist(country_df['Rating'], bins=10)
    plt.xlabel('Rating')
    plt.ylabel('Frequency')
    plt.title(f'Rating Histogram for {country} Red Wine')
    plt.show()

    # Scatterplot of Price vs. Rating
    plt.figure(figsize=(8, 6))
    plt.scatter(country_df['Price'], country_df['Rating'])
    plt.xlabel('Price')
    plt.ylabel('Rating')
    plt.title(f'Price vs. Rating Scatterplot for {country} Red Wine')
    plt.show()

# %%
# prompt: For each country in the white wine dataset, create a histogram of Price, a histogram of Rating, and a scatterplot of Price vs. Rating

# Assuming white_df is already defined and loaded with data
# If not, load the data first:
# white_df = pd.read_csv("White.csv")

for country in white_df['Country'].unique():
    country_df = white_df[white_df['Country'] == country]

    # Price Histogram
    plt.figure(figsize=(8, 6))
    plt.hist(country_df['Price'], bins=10)
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.title(f'Price Histogram for {country} White Wine')
    plt.show()

    # Rating Histogram
    plt.figure(figsize=(8, 6))
    plt.hist(country_df['Rating'], bins=10)
    plt.xlabel('Rating')
    plt.ylabel('Frequency')
    plt.title(f'Rating Histogram for {country} White Wine')
    plt.show()

    # Scatterplot of Price vs. Rating
    plt.figure(figsize=(8, 6))
    plt.scatter(country_df['Price'], country_df['Rating'])
    plt.xlabel('Price')
    plt.ylabel('Rating')
    plt.title(f'Price vs. Rating Scatterplot for {country} White Wine')
    plt.show()

# %%
# prompt: For each country in the rose wine dataset, create a histogram of Price, a histogram of Rating, and a scatterplot of Price vs. Rating

import pandas as pd
import matplotlib.pyplot as plt

# Assuming rose_df is already defined and loaded with data
# If not, load the data first:
# rose_df = pd.read_csv("Rose.csv")

for country in rose_df['Country'].unique():
    country_df = rose_df[rose_df['Country'] == country]

    # Price Histogram
    plt.figure(figsize=(8, 6))
    plt.hist(country_df['Price'], bins=10)
    plt.xlabel('Price')
    plt.ylabel('Frequency')
    plt.title(f'Price Histogram for {country} Rose Wine')
    plt.show()

    # Rating Histogram
    plt.figure(figsize=(8, 6))
    plt.hist(country_df['Rating'], bins=10)
    plt.xlabel('Rating')
    plt.ylabel('Frequency')
    plt.title(f'Rating Histogram for {country} Rose Wine')
    plt.show()

    # Scatterplot of Price vs. Rating
    plt.figure(figsize=(8, 6))
    plt.scatter(country_df['Price'], country_df['Rating'])
    plt.xlabel('Price')
    plt.ylabel('Rating')
    plt.title(f'Price vs. Rating Scatterplot for {country} Rose Wine')
    plt.show()

# %%
# prompt: box-lots of price distribution based on wine type color

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming filtered_wine_df is defined as in your previous code
plt.figure(figsize=(12, 6))
sns.boxplot(x='wine_type', y='Price', data=filtered_wine_df)
plt.title('Price Distribution by Wine Type')
plt.xlabel('Wine Type')
plt.ylabel('Price')
plt.show()

# %%
# prompt: create box-lots of the price distribution based on wine type

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming wine_df is already defined and loaded as in the previous example
plt.figure(figsize=(10, 6))
sns.boxplot(x='wine_type', y='Price', data=filtered_wine_df)
plt.title('Price Distribution by Wine Type')
plt.xlabel('Wine Type')
plt.ylabel('Price')
plt.show()

# %%
# prompt: # prompt: create box-plots of rating by wine type match the colors accordingly

# Assuming filtered_wine_df is already defined and loaded as in the previous example
plt.figure(figsize=(10, 6))
sns.boxplot(x='wine_type', y='Rating', data=filtered_wine_df, palette={'Red': 'red', 'White': 'grey', 'Rose': 'pink', 'Sparkling': 'gold'})
plt.title('Rating Distribution by Wine Type')
plt.xlabel('Wine Type')
plt.ylabel('Rating')
plt.show()
# Out:
# <ipython-input-53-9563db25e620>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# prompt: create box-plots of rating by wine tyoe

# Assuming wine_df is already defined and loaded as in the previous example
plt.figure(figsize=(10, 6))
sns.boxplot(x='wine_type', y='Rating', data=filtered_wine_df)
plt.title('Rating Distribution by Wine Type')
plt.xlabel('Wine Type')
plt.ylabel('Rating')
plt.show()

# %%
# prompt: create box-plots of price vs rating by wine type match the colors accordingly

import matplotlib.pyplot as plt
import seaborn as sns

# Assuming filtered_wine_df is already defined and loaded as in the previous example
plt.figure(figsize=(10, 6))
sns.boxplot(x='wine_type', y='Price', hue='wine_type', data=filtered_wine_df, palette={'Red': 'red', 'White': 'grey', 'Rose': 'pink', 'Sparkling': 'gold'})
plt.title('Price Distribution vs Rating by Wine Type')
plt.xlabel('Wine Type')
plt.ylabel('Price')
plt.show()
